# %%
from matplotlib import pyplot as plt
import cv2

img_path = 'alien3.png'
# img_path = 'spaceship5.png'
img = cv2.imread('/home/user/PycharmProjects/Python_zadania_Luda/Github/game/game_space_ship/data/' + img_path, cv2.IMREAD_UNCHANGED)
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(img.shape)
channel = img.copy()
# set green and red channels to 0
channel[:, :, 0] = 0
channel[:, :, 1] = 0
channel[:, :, 2] = 0
plt.imshow(channel)
plt.title('my picture')
plt.show()
# Out:
# (71, 80, 4)
